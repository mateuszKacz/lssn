# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Pobierz pliki csv z katalogu `~/tomgrad/lssn`
#
# `cp ~/tomgrad/lssn/mnist_train .`
#
# `cp ~/tomgrad/lssn/mnist_test .`
#
# UWAGA: pliki zajmują łącznie ponad 120MB.

# %%
train_data = loadtxt("mnist_train.csv", delimiter=",")

# %%
test_data = loadtxt("mnist_test.csv", delimiter=",")

# %%
for n in range(16):
    subplot(4,4,n+1)
    axis('off')
    imshow(train_data[n,1:].reshape(28,28))
    title(train_data[n,0])

    tight_layout()

# %%
subplot(121)
imshow(test_data[n,1:].reshape(28,28))
subplot(122)
imshow(test_data[n,1:].reshape(28,28)>128)
