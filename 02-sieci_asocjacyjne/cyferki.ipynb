# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Wypakuj pliki z danymi
#
# `unzip mnist.zip`
#
# UWAGA: pliki zajmują łącznie ponad 120MB. Po przekroczeniu quoty możesz się nie zalogować w trybie graficznym.

# %%
train_data = loadtxt("mnist_train.csv", delimiter=",")

# %%
test_data = loadtxt("mnist_test.csv", delimiter=",")

# %%
for n in range(16):
    subplot(4,4,n+1)
    axis('off')
    imshow(train_data[n,1:].reshape(28,28))
    title(train_data[n,0])

# %%
subplot(141)
imshow(test_data[n,1:].reshape(28,28))
subplot(142)
imshow(test_data[n,1:].reshape(28,28)>192)
subplot(143)
imshow(test_data[n,1:].reshape(28,28)>128)
subplot(144)
imshow(test_data[n,1:].reshape(28,28)>64)
